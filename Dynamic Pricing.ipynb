# %%
# !pip install pandas

# %%
 import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_csv('DataSet/discountSet.csv')

# %%
df1.head()
# Out:
#                     Race/Etnicity Female Percentage Male Percentage  \
# 0  White (Not Hispanic or Latino)               16%             36%
# 1              Hispanic or Latino                7%              4%
# 2                           Other                3%              1%
# 3                     Undisclosed                4%              4%
# 4  Asian (Not Hispanic or Latino)                5%              2%
#
#   Grand Total
# 0         52%
# 1         11%
# 2          3%
# 3          8%
# 4          7%

# %%
df2 = pd.read_csv('DataSet/priceData.csv')
df2.head()
# Out:
#                 event_time      order_id    product_id   category_id  \
# 0  2020-04-24 11:50:39 UTC  2.294360e+18  1.515970e+18  2.268105e+18
# 1  2020-04-24 11:50:39 UTC  2.294360e+18  1.515970e+18  2.268110e+18
# 2  2020-04-24 14:37:43 UTC  2.294440e+18  2.273950e+18  2.268110e+18
# 3  2020-04-24 14:37:43 UTC  2.294440e+18  2.273950e+18  2.268110e+18
# 4  2020-04-24 19:16:21 UTC  2.294580e+18  2.273950e+18  2.268110e+18
#
#                  category_code    brand   price       user_id
# 0           electronics.tablet  samsung  162.01  1.515920e+18
# 1           electronics.tablet  samsung  162.01  1.515920e+18
# 2  electronics.audio.headphone   huawei   77.52  1.515920e+18
# 3  electronics.audio.headphone   huawei   77.52  1.515920e+18
# 4                          NaN  karcher  217.57  1.515920e+18

# %%
df3 = pd.read_csv('DataSet/SalesData.csv')
df3.head()
# Out:
#   Sales Representative       Location Region         Customer  Order Date  \
# 0          Sara Snyder  Massachusetts   East    Raymond Young  2016-01-01
# 1          Sara Snyder       New York   East       Helen Dean  2016-01-01
# 2       Diane Gonzalez     Washington   West   Shirley Chavez  2016-01-01
# 3          Sara Snyder     New Jersey   East       Brian Ryan  2016-01-01
# 4          Sara Snyder     New Jersey   East  Benjamin Willis  2016-01-01
#
#      Item  Quantity  Price  Total Sale Amount
# 0    Junk         6  12.42              74.52
# 1    Junk         7  12.42              86.94
# 2   Stuff         2  16.32              32.64
# 3    Junk         1  12.42              12.42
# 4  Things         3  17.83              53.49

# %%
df = pd.concat([df1,df2,df3],axis=1)
df.head()
# Out:
#                     Race/Etnicity Female Percentage Male Percentage  \
# 0  White (Not Hispanic or Latino)               16%             36%
# 1              Hispanic or Latino                7%              4%
# 2                           Other                3%              1%
# 3                     Undisclosed                4%              4%
# 4  Asian (Not Hispanic or Latino)                5%              2%
#
#   Grand Total               event_time      order_id    product_id  \
# 0         52%  2020-04-24 11:50:39 UTC  2.294360e+18  1.515970e+18
# 1         11%  2020-04-24 11:50:39 UTC  2.294360e+18  1.515970e+18
# 2          3%  2020-04-24 14:37:43 UTC  2.294440e+18  2.273950e+18
# 3          8%  2020-04-24 14:37:43 UTC  2.294440e+18  2.273950e+18
# 4          7%  2020-04-24 19:16:21 UTC  2.294580e+18  2.273950e+18
#
#     category_id                category_code    brand  ...       user_id  \
# 0  2.268105e+18           electronics.tablet  samsung  ...  1.515920e+18
# ...

# %%
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6b3f50303a97> in <module>
# ----> 1 print(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %%
df = df.dropna()
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#                                        Race/Etnicity Female Percentage  \
# 0                     White (Not Hispanic or Latino)               16%
# 1                                 Hispanic or Latino                7%
# 2                                              Other                3%
# 3                                        Undisclosed                4%
# 4  Black or African American (Not Hispanic or Lat...                7%
#
#   Male Percentage Grand Total               event_time      order_id  \
# 0             36%         52%  2020-04-24 11:50:39 UTC  2.294360e+18
# 1              4%         11%  2020-04-24 11:50:39 UTC  2.294360e+18
# 2              1%          3%  2020-04-24 14:37:43 UTC  2.294440e+18
# 3              4%          8%  2020-04-24 14:37:43 UTC  2.294440e+18
# 4             12%         19%  2020-04-26 08:45:57 UTC  2.295720e+18
#
#      product_id   category_id                category_code    brand  ...  \
# ...

# %%
df.drop(['user_id'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                        Race/Etnicity Female Percentage  \
# 0                     White (Not Hispanic or Latino)               16%
# 1                                 Hispanic or Latino                7%
# 2                                              Other                3%
# 3                                        Undisclosed                4%
# 4  Black or African American (Not Hispanic or Lat...                7%
#
#   Male Percentage Grand Total               event_time      order_id  \
# 0             36%         52%  2020-04-24 11:50:39 UTC  2.294360e+18
# 1              4%         11%  2020-04-24 11:50:39 UTC  2.294360e+18
# 2              1%          3%  2020-04-24 14:37:43 UTC  2.294440e+18
# 3              4%          8%  2020-04-24 14:37:43 UTC  2.294440e+18
# 4             12%         19%  2020-04-26 08:45:57 UTC  2.295720e+18
#
#      product_id   category_id                category_code    brand   price  \
# ...

# %%
df.drop(['Customer'], axis = 1,inplace=True)

# %%
df.head()
# Out:
#                                        Race/Etnicity Female Percentage  \
# 0                     White (Not Hispanic or Latino)               16%
# 1                                 Hispanic or Latino                7%
# 2                                              Other                3%
# 3                                        Undisclosed                4%
# 4  Black or African American (Not Hispanic or Lat...                7%
#
#   Male Percentage Grand Total               event_time      order_id  \
# 0             36%         52%  2020-04-24 11:50:39 UTC  2.294360e+18
# 1              4%         11%  2020-04-24 11:50:39 UTC  2.294360e+18
# 2              1%          3%  2020-04-24 14:37:43 UTC  2.294440e+18
# 3              4%          8%  2020-04-24 14:37:43 UTC  2.294440e+18
# 4             12%         19%  2020-04-26 08:45:57 UTC  2.295720e+18
#
#      product_id   category_id                category_code    brand   price  \
# ...

# %%
print(len(df.columns))
# Out:
# 20

# %%
df["TotalAmount"] = df["price"]+df["Total Sale Amount"]

# %%
df
# Out:
#                                        Race/Etnicity Female Percentage  \
# 0                     White (Not Hispanic or Latino)               16%
# 1                                 Hispanic or Latino                7%
# 2                                              Other                3%
# 3                                        Undisclosed                4%
# 4  Black or African American (Not Hispanic or Lat...                7%
#
#   Male Percentage Grand Total               event_time      order_id  \
# 0             36%         52%  2020-04-24 11:50:39 UTC  2.294360e+18
# 1              4%         11%  2020-04-24 11:50:39 UTC  2.294360e+18
# 2              1%          3%  2020-04-24 14:37:43 UTC  2.294440e+18
# 3              4%          8%  2020-04-24 14:37:43 UTC  2.294440e+18
# 4             12%         19%  2020-04-26 08:45:57 UTC  2.295720e+18
#
#      product_id   category_id                category_code    brand   price  \
# ...

# %%
df.head()
# Out:
#                                        Race/Etnicity Female Percentage  \
# 0                     White (Not Hispanic or Latino)               16%
# 1                                 Hispanic or Latino                7%
# 2                                              Other                3%
# 3                                        Undisclosed                4%
# 4  Black or African American (Not Hispanic or Lat...                7%
#
#   Male Percentage Grand Total               event_time      order_id  \
# 0             36%         52%  2020-04-24 11:50:39 UTC  2.294360e+18
# 1              4%         11%  2020-04-24 11:50:39 UTC  2.294360e+18
# 2              1%          3%  2020-04-24 14:37:43 UTC  2.294440e+18
# 3              4%          8%  2020-04-24 14:37:43 UTC  2.294440e+18
# 4             12%         19%  2020-04-26 08:45:57 UTC  2.295720e+18
#
#      product_id   category_id                category_code    brand   price  \
# ...

# %%
df.drop(['Race/Etnicity','event_time','order_id','product_id','category_id'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Female Percentage Male Percentage Grand Total                category_code  \
# 0               16%             36%         52%           electronics.tablet
# 1                7%              4%         11%           electronics.tablet
# 2                3%              1%          3%  electronics.audio.headphone
# 3                4%              4%          8%  electronics.audio.headphone
# 4                7%             12%         19%      furniture.kitchen.table
#
#      brand   price Sales Representative       Location Region  Order Date  \
# 0  samsung  162.01          Sara Snyder  Massachusetts   East  2016-01-01
# 1  samsung  162.01          Sara Snyder       New York   East  2016-01-01
# 2   huawei   77.52       Diane Gonzalez     Washington   West  2016-01-01
# 3   huawei   77.52          Sara Snyder     New Jersey   East  2016-01-01
# 4  maestro   39.33       Patrick Graham     Washington   West  2016-01-01
#
# ...

# %%
df = pd.concat([df, pd.get_dummies(df['brand'])], axis=1)

# %%
df.head()
# Out:
#   Female Percentage Male Percentage Grand Total                category_code  \
# 0               16%             36%         52%           electronics.tablet
# 1                7%              4%         11%           electronics.tablet
# 2                3%              1%          3%  electronics.audio.headphone
# 3                4%              4%          8%  electronics.audio.headphone
# 4                7%             12%         19%      furniture.kitchen.table
#
#      brand   price Sales Representative       Location Region  Order Date  \
# 0  samsung  162.01          Sara Snyder  Massachusetts   East  2016-01-01
# 1  samsung  162.01          Sara Snyder       New York   East  2016-01-01
# 2   huawei   77.52       Diane Gonzalez     Washington   West  2016-01-01
# 3   huawei   77.52          Sara Snyder     New Jersey   East  2016-01-01
# 4  maestro   39.33       Patrick Graham     Washington   West  2016-01-01
#
# ...

# %%
df.drop('brand',axis=1)
# Out:
#   Female Percentage Male Percentage Grand Total                category_code  \
# 0               16%             36%         52%           electronics.tablet
# 1                7%              4%         11%           electronics.tablet
# 2                3%              1%          3%  electronics.audio.headphone
# 3                4%              4%          8%  electronics.audio.headphone
# 4                7%             12%         19%      furniture.kitchen.table
#
#     price Sales Representative       Location Region  Order Date     Item  \
# 0  162.01          Sara Snyder  Massachusetts   East  2016-01-01     Junk
# 1  162.01          Sara Snyder       New York   East  2016-01-01     Junk
# 2   77.52       Diane Gonzalez     Washington   West  2016-01-01    Stuff
# 3   77.52          Sara Snyder     New Jersey   East  2016-01-01     Junk
# 4   39.33       Patrick Graham     Washington   West  2016-01-01  Widgets
#
# ...

# %%
df.drop(['Sales Representative','Order Date','Item'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Female Percentage Male Percentage Grand Total                category_code  \
# 0               16%             36%         52%           electronics.tablet
# 1                7%              4%         11%           electronics.tablet
# 2                3%              1%          3%  electronics.audio.headphone
# 3                4%              4%          8%  electronics.audio.headphone
# 4                7%             12%         19%      furniture.kitchen.table
#
#      brand   price       Location Region  Quantity  Price  Total Sale Amount  \
# 0  samsung  162.01  Massachusetts   East       6.0  12.42              74.52
# 1  samsung  162.01       New York   East       7.0  12.42              86.94
# 2   huawei   77.52     Washington   West       2.0  16.32              32.64
# 3   huawei   77.52     New Jersey   East       1.0  12.42              12.42
# 4  maestro   39.33     Washington   West       6.0  53.35             320.10
#
# ...

# %%
df = pd.concat([df, pd.get_dummies(df['category_code'])],axis=1)

# %%
df=pd.concat([df,pd.get_dummies(df['Location'])],axis=1)

# %%
df=pd.concat([df,pd.get_dummies(df['Region'])],axis=1)

# %%
df.head()
# Out:
#   Female Percentage Male Percentage Grand Total                category_code  \
# 0               16%             36%         52%           electronics.tablet
# 1                7%              4%         11%           electronics.tablet
# 2                3%              1%          3%  electronics.audio.headphone
# 3                4%              4%          8%  electronics.audio.headphone
# 4                7%             12%         19%      furniture.kitchen.table
#
#      brand   price       Location Region  Quantity  Price  ...  samsung  \
# 0  samsung  162.01  Massachusetts   East       6.0  12.42  ...        1
# 1  samsung  162.01       New York   East       7.0  12.42  ...        1
# 2   huawei   77.52     Washington   West       2.0  16.32  ...        0
# 3   huawei   77.52     New Jersey   East       1.0  12.42  ...        0
# 4  maestro   39.33     Washington   West       6.0  53.35  ...        0
#
# ...

# %%
df.drop(['brand','Location','Region','category_code'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Female Percentage Male Percentage Grand Total   price  Quantity  Price  \
# 0               16%             36%         52%  162.01       6.0  12.42
# 1                7%              4%         11%  162.01       7.0  12.42
# 2                3%              1%          3%   77.52       2.0  16.32
# 3                4%              4%          8%   77.52       1.0  12.42
# 4                7%             12%         19%   39.33       6.0  53.35
#
#    Total Sale Amount  TotalAmount  huawei  maestro  samsung  \
# 0              74.52       236.53       0        0        1
# 1              86.94       248.95       0        0        1
# 2              32.64       110.16       1        0        0
# 3              12.42        89.94       1        0        0
# 4             320.10       359.43       0        1        0
#
#    electronics.audio.headphone  electronics.tablet  furniture.kitchen.table  \
# 0                            0                   1                        0
# ...

# %%
df.drop('Quantity',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-d943dc66a7cb> in <module>
# ----> 1 df.drop('Quantity',axis=1,inplace=True)
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df['Female Percentage']= df['Female Percentage'].str.rstrip('%').astype(float) / 100

# %%
df.head()
# Out:
#    Female Percentage  Male Percentage Grand Total   price  Price  \
# 0               0.16             0.36         52%  162.01  12.42
# 1               0.07             0.04         11%  162.01  12.42
# 2               0.03             0.01          3%   77.52  16.32
# 3               0.04             0.04          8%   77.52  12.42
# 4               0.07             0.12         19%   39.33  53.35
#
#    Total Sale Amount  TotalAmount  huawei  maestro  samsung  \
# 0              74.52       236.53       0        0        1
# 1              86.94       248.95       0        0        1
# 2              32.64       110.16       1        0        0
# 3              12.42        89.94       1        0        0
# 4             320.10       359.43       0        1        0
#
#    electronics.audio.headphone  electronics.tablet  furniture.kitchen.table  \
# 0                            0                   1                        0
# ...

# %%
fp =df["Female Percentage"]
fp
# Out:
# 0    16%
# 1     7%
# 2     3%
# 3     4%
# 4     7%
# Name: Female Percentage, dtype: object

# %%
df.head()
# Out:
#    Female Percentage  Male Percentage Grand Total   price  Price  \
# 0               0.16             0.36         52%  162.01  12.42
# 1               0.07             0.04         11%  162.01  12.42
# 2               0.03             0.01          3%   77.52  16.32
# 3               0.04             0.04          8%   77.52  12.42
# 4               0.07             0.12         19%   39.33  53.35
#
#    Total Sale Amount  TotalAmount  huawei  maestro  samsung  \
# 0              74.52       236.53       0        0        1
# 1              86.94       248.95       0        0        1
# 2              32.64       110.16       1        0        0
# 3              12.42        89.94       1        0        0
# 4             320.10       359.43       0        1        0
#
#    electronics.audio.headphone  electronics.tablet  furniture.kitchen.table  \
# 0                            0                   1                        0
# ...

# %%
MP =df["Male Percentage"]
MP
# Out:
# 0    36%
# 1     4%
# 2     1%
# 3     4%
# 4    12%
# Name: Male Percentage, dtype: object

# %%
df['Male Percentage']= df['Male Percentage'].str.rstrip('%').astype(float) / 100

# %%
df.head()
# Out:
#   Female Percentage  Male Percentage Grand Total   price  Price  \
# 0               16%             0.36         52%  162.01  12.42
# 1                7%             0.04         11%  162.01  12.42
# 2                3%             0.01          3%   77.52  16.32
# 3                4%             0.04          8%   77.52  12.42
# 4                7%             0.12         19%   39.33  53.35
#
#    Total Sale Amount  TotalAmount  huawei  maestro  samsung  \
# 0              74.52       236.53       0        0        1
# 1              86.94       248.95       0        0        1
# 2              32.64       110.16       1        0        0
# 3              12.42        89.94       1        0        0
# 4             320.10       359.43       0        1        0
#
#    electronics.audio.headphone  electronics.tablet  furniture.kitchen.table  \
# 0                            0                   1                        0
# ...

# %%
df['Grand Total']= df['Grand Total'].str.rstrip('%').astype(float) / 100

# %%
df.drop(['fpint','fp','fpi'],axis=1,inplace=True)

# %%
df.drop('Grand Total',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Female Percentage  Male Percentage   price  Price  Total Sale Amount  \
# 0               0.16             0.36  162.01  12.42              74.52
# 1               0.07             0.04  162.01  12.42              86.94
# 2               0.03             0.01   77.52  16.32              32.64
# 3               0.04             0.04   77.52  12.42              12.42
# 4               0.07             0.12   39.33  53.35             320.10
#
#    TotalAmount  huawei  maestro  samsung  electronics.audio.headphone  \
# 0       236.53       0        0        1                            0
# 1       248.95       0        0        1                            0
# 2       110.16       1        0        0                            1
# 3        89.94       1        0        0                            1
# 4       359.43       0        1        0                            0
#
#    electronics.tablet  furniture.kitchen.table  Massachusetts  New Jersey  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
avgtotal=df["TotalAmount"].mean()

# %%
avgtotal
# Out:
# 209.002

# %%
tamount= df["TotalAmount"]

# %%
len(tamount)
# Out:
# 5

# %%
max(tamount)
# Out:
# 359.43

# %%
min(tamount)
# Out:
# 89.94

# %%
avgtotal = 209.002
def inc_dec(TotalAmount):
    if TotalAmount >= avgtotal:
        print("The Total_Amount {} is increasing".format(TotalAmount))
    else:
        print("The Total_Amount {} is decreasing".format(TotalAmount))

# %%
inc_dec(200)
# Out:
# The Total_Amount 200 is decreasing

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
x=df.iloc[:,[4,5]].values

# %%
df.head()
# Out:
#    Female Percentage  Male Percentage   price  Price  Total Sale Amount  \
# 0               0.16             0.36  162.01  12.42              74.52
# 1               0.07             0.04  162.01  12.42              86.94
# 2               0.03             0.01   77.52  16.32              32.64
# 3               0.04             0.04   77.52  12.42              12.42
# 4               0.07             0.12   39.33  53.35             320.10
#
#    TotalAmount  huawei  maestro  samsung  electronics.audio.headphone  \
# 0       236.53       0        0        1                            0
# 1       248.95       0        0        1                            0
# 2       110.16       1        0        0                            1
# 3        89.94       1        0        0                            1
# 4       359.43       0        1        0                            0
#
#    electronics.tablet  furniture.kitchen.table  Massachusetts  New Jersey  \
# ...

# %%
x
# Out:
# array([[ 74.52, 236.53],
#        [ 86.94, 248.95],
#        [ 32.64, 110.16],
#        [ 12.42,  89.94],
#        [320.1 , 359.43]])

# %%
from sklearn.cluster import KMeans
from sklearn import metrics

# %%
wcss=[]
for i in range(1,5):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    true_label = kmeans.fit(x)
    print(true_label)
    pred = kmeans.labels_
    print(pred)
    print(metrics.rand_score(true_label.labels_,pred))
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\vgaurav5\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=1, random_state=0)
# [0 0 0 0 0]
# 1.0
# KMeans(n_clusters=2, random_state=0)
# [1 1 1 1 0]
# 1.0
# KMeans(n_clusters=3, random_state=0)
# [2 2 1 1 0]
# 1.0
# KMeans(n_clusters=4, random_state=0)
# [2 2 1 3 0]
# 1.0

# %%
plt.plot(range(1,5),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans=KMeans(n_clusters=2,init='k-means++',random_state=0)
y_kmeans=kmeans.fit_predict(x)

# %%
plt.scatter(x[y_kmeans==0,0],x[y_kmeans==0,1],s=100,c='red',label='Cluster1')
plt.scatter(x[y_kmeans==1,0],x[y_kmeans==1,1],s=100,c='blue',label='Cluster2')

# %%
kmeans=KMeans(n_clusters=2,init='k-means++',random_state=0)
y_kmeans=kmeans.fit_predict(x)
plt.scatter(x[y_kmeans==0,0],X[y_kmeans==0,1],s=100,c='red',label='Cluster1')
plt.scatter(x[y_kmeans==1,0],X[y_kmeans==1,1],s=100,c='blue',label='Cluster2')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='yellow',label='Centroids')
plt.title('clusture of sales')
plt.xlabel('Total Sale Amount')
plt.ylabel('TotalAmount')
plt.legend()
plt.show()

# %%
df.head()
# Out:
#    Female Percentage  Male Percentage   price  Price  Total Sale Amount  \
# 0               0.16             0.36  162.01  12.42              74.52
# 1               0.07             0.04  162.01  12.42              86.94
# 2               0.03             0.01   77.52  16.32              32.64
# 3               0.04             0.04   77.52  12.42              12.42
# 4               0.07             0.12   39.33  53.35             320.10
#
#    TotalAmount  huawei  maestro  samsung  electronics.audio.headphone  \
# 0       236.53       0        0        1                            0
# 1       248.95       0        0        1                            0
# 2       110.16       1        0        0                            1
# 3        89.94       1        0        0                            1
# 4       359.43       0        1        0                            0
#
#    electronics.tablet  furniture.kitchen.table  Massachusetts  New Jersey  \
# ...
